# %%
import pandas as pd

# %%
data = [
    {
        "No.": 1,
        "Website / Institution": "Central Bank of Sri Lanka",
        "URL": "https://www.cbsl.gov.lk",
        "Type of Data": "Exchange rates, inflation, monetary policy, economic indicators",
        "Suitable Tools": "requests, BeautifulSoup",
        "Notes": "Exchange rate tables are static and easy to parse"
    },
    {
        "No.": 2,
        "Website / Institution": "Department of Census & Statistics",
        "URL": "https://www.statistics.gov.lk",
        "Type of Data": "Labour, population, agriculture, economic reports",
        "Suitable Tools": "requests, BeautifulSoup, PyPDF2, OCR",
        "Notes": "Some reports are in PDF, useful for OCR tasks"
    },
    {
        "No.": 3,
        "Website / Institution": "IRCSL",
        "URL": "https://www.ircsl.gov.lk",
        "Type of Data": "Insurance statistics, circulars, company lists",
        "Suitable Tools": "requests, BeautifulSoup, PyPDF2",
        "Notes": "Good for PDF scraping and extracting structured tables"
    },
    {
        "No.": 4,
        "Website / Institution": "Colombo Stock Exchange (CSE)",
        "URL": "https://www.cse.lk",
        "Type of Data": "Stock prices, company data, announcements",
        "Suitable Tools": "Selenium",
        "Notes": "Dynamic content; use Selenium to interact with dropdowns"
    },
    {
        "No.": 5,
        "Website / Institution": "Ministry of Finance",
        "URL": "https://www.treasury.gov.lk",
        "Type of Data": "Budget documents, economic policy, reports",
        "Suitable Tools": "PyPDF2, OCR",
        "Notes": "Reports are mostly PDF — ideal for document extraction"
    },
    {
        "No.": 6,
        "Website / Institution": "PUCSL",
        "URL": "https://www.pucsl.gov.lk",
        "Type of Data": "Electricity tariffs, regulations, complaints data",
        "Suitable Tools": "requests, BeautifulSoup",
        "Notes": "Website structure is clean and beginner-friendly"
    },
    {
        "No.": 7,
        "Website / Institution": "Sri Lanka Customs",
        "URL": "http://www.customs.gov.lk",
        "Type of Data": "Trade regulations, duty calculators, circulars",
        "Suitable Tools": "BeautifulSoup, Selenium",
        "Notes": "Basic site; data hidden in nested HTML or PDFs"
    },
    {
        "No.": 8,
        "Website / Institution": "Elections Commission",
        "URL": "https://www.elections.gov.lk",
        "Type of Data": "Election results, turnout, polling info",
        "Suitable Tools": "BeautifulSoup, PyPDF2",
        "Notes": "Great for scraping result tables from past elections"
    },
    {
        "No.": 9,
        "Website / Institution": "Sri Lanka Ports Authority",
        "URL": "http://www.slpa.lk",
        "Type of Data": "Port statistics, maritime notices",
        "Suitable Tools": "requests, BeautifulSoup",
        "Notes": "Data includes traffic stats and reports"
    },
    {
        "No.": 10,
        "Website / Institution": "National Transport Commission (NTC)",
        "URL": "https://www.ntc.gov.lk",
        "Type of Data": "Bus fares, transport schedules, permits",
        "Suitable Tools": "BeautifulSoup, OCR",
        "Notes": "Fare tables or route lists available for scraping or OCR"
    },
    {
        "No.": 11,
        "Website / Institution": "Sri Lanka Tourism Promotion Bureau",
        "URL": "https://www.srilanka.travel",
        "Type of Data": "Tourist arrival statistics, travel advisories, promotional material",
        "Suitable Tools": "requests, BeautifulSoup, Selenium",
        "Notes": "Includes monthly arrival data tables; some sections are JavaScript-rendered"
    }
]

df = pd.DataFrame(data)
df
# Out:
#     No.                Website / Institution                            URL  \
# 0     1            Central Bank of Sri Lanka        https://www.cbsl.gov.lk
# 1     2    Department of Census & Statistics  https://www.statistics.gov.lk
# 2     3                                IRCSL       https://www.ircsl.gov.lk
# 3     4         Colombo Stock Exchange (CSE)             https://www.cse.lk
# 4     5                  Ministry of Finance    https://www.treasury.gov.lk
# 5     6                                PUCSL       https://www.pucsl.gov.lk
# 6     7                    Sri Lanka Customs      http://www.customs.gov.lk
# 7     8                 Elections Commission   https://www.elections.gov.lk
# 8     9            Sri Lanka Ports Authority             http://www.slpa.lk
# 9    10  National Transport Commission (NTC)         https://www.ntc.gov.lk
# 10   11   Sri Lanka Tourism Promotion Bureau    https://www.srilanka.travel
#
#                                          Type of Data  \
# 0   Exchange rates, inflation, monetary policy, ec...
# 1   Labour, population, agriculture, economic reports
# 2      Insurance statistics, circulars, company lists
# 3           Stock prices, company data, announcements
# 4          Budget documents, economic policy, reports
# 5   Electricity tariffs, regulations, complaints data
# 6      Trade regulations, duty calculators, circulars
# 7             Election results, turnout, polling info
# 8                   Port statistics, maritime notices
# 9             Bus fares, transport schedules, permits
# 10  Tourist arrival statistics, travel advisories,...
#
#                           Suitable Tools  \
# 0                requests, BeautifulSoup
# 1   requests, BeautifulSoup, PyPDF2, OCR
# 2        requests, BeautifulSoup, PyPDF2
# 3                               Selenium
# 4                            PyPDF2, OCR
# 5                requests, BeautifulSoup
# 6                BeautifulSoup, Selenium
# 7                  BeautifulSoup, PyPDF2
# 8                requests, BeautifulSoup
# 9                     BeautifulSoup, OCR
# 10     requests, BeautifulSoup, Selenium
#
#                                                 Notes
# 0   Exchange rate tables are static and easy to parse
# 1       Some reports are in PDF, useful for OCR tasks
# 2   Good for PDF scraping and extracting structure...
# 3   Dynamic content; use Selenium to interact with...
# 4   Reports are mostly PDF — ideal for document ex...
# 5    Website structure is clean and beginner-friendly
# 6      Basic site; data hidden in nested HTML or PDFs
# 7   Great for scraping result tables from past ele...
# 8             Data includes traffic stats and reports
# 9   Fare tables or route lists available for scrap...
# 10  Includes monthly arrival data tables; some sec...

# %%
df = pd.DataFrame(data)
df
# Out:
#     No.                Website / Institution                            URL  \
# 0     1            Central Bank of Sri Lanka        https://www.cbsl.gov.lk
# 1     2    Department of Census & Statistics  https://www.statistics.gov.lk
# 2     3                                IRCSL       https://www.ircsl.gov.lk
# 3     4         Colombo Stock Exchange (CSE)             https://www.cse.lk
# 4     5                  Ministry of Finance    https://www.treasury.gov.lk
# 5     6                                PUCSL       https://www.pucsl.gov.lk
# 6     7                    Sri Lanka Customs      http://www.customs.gov.lk
# 7     8                 Elections Commission   https://www.elections.gov.lk
# 8     9            Sri Lanka Ports Authority             http://www.slpa.lk
# 9    10  National Transport Commission (NTC)         https://www.ntc.gov.lk
# 10   11   Sri Lanka Tourism Promotion Bureau    https://www.srilanka.travel
#
#                                          Type of Data  \
# 0   Exchange rates, inflation, monetary policy, ec...
# 1   Labour, population, agriculture, economic reports
# 2      Insurance statistics, circulars, company lists
# 3           Stock prices, company data, announcements
# 4          Budget documents, economic policy, reports
# 5   Electricity tariffs, regulations, complaints data
# 6      Trade regulations, duty calculators, circulars
# 7             Election results, turnout, polling info
# 8                   Port statistics, maritime notices
# 9             Bus fares, transport schedules, permits
# 10  Tourist arrival statistics, travel advisories,...
#
#                           Suitable Tools  \
# 0                requests, BeautifulSoup
# 1   requests, BeautifulSoup, PyPDF2, OCR
# 2        requests, BeautifulSoup, PyPDF2
# 3                               Selenium
# 4                            PyPDF2, OCR
# 5                requests, BeautifulSoup
# 6                BeautifulSoup, Selenium
# 7                  BeautifulSoup, PyPDF2
# 8                requests, BeautifulSoup
# 9                     BeautifulSoup, OCR
# 10     requests, BeautifulSoup, Selenium
#
#                                                 Notes
# 0   Exchange rate tables are static and easy to parse
# 1       Some reports are in PDF, useful for OCR tasks
# 2   Good for PDF scraping and extracting structure...
# 3   Dynamic content; use Selenium to interact with...
# 4   Reports are mostly PDF — ideal for document ex...
# 5    Website structure is clean and beginner-friendly
# 6      Basic site; data hidden in nested HTML or PDFs
# 7   Great for scraping result tables from past ele...
# 8             Data includes traffic stats and reports
# 9   Fare tables or route lists available for scrap...
# 10  Includes monthly arrival data tables; some sec...

# %%
df.to_csv("Topics.csv")

# %%
URL_list = df['URL']
URL_list
# Out:
# 0           https://www.cbsl.gov.lk
# 1     https://www.statistics.gov.lk
# 2          https://www.ircsl.gov.lk
# 3                https://www.cse.lk
# 4       https://www.treasury.gov.lk
# 5          https://www.pucsl.gov.lk
# 6         http://www.customs.gov.lk
# 7      https://www.elections.gov.lk
# 8                http://www.slpa.lk
# 9            https://www.ntc.gov.lk
# 10      https://www.srilanka.travel
# Name: URL, dtype: object

# %%
URL_list[1][8:]
# Out:
# 'www.statistics.gov.lk'

# %%
import requests

for link in URL_list:
    url = link
    if url == "https://www.ircsl.gov.lk":
        print(url[8:],":","skip IRCSL")
    else:
        response = requests.get(url)
        print(url[8:],":",response.status_code)
# Out:
# www.cbsl.gov.lk : 200
# www.statistics.gov.lk : 200
# www.ircsl.gov.lk : skip IRCSL
# www.cse.lk : 200
# www.treasury.gov.lk : 200
# www.pucsl.gov.lk : 200
# ww.customs.gov.lk : 200
# www.elections.gov.lk : 200
# ww.slpa.lk : 200
# www.ntc.gov.lk : 200
# www.srilanka.travel : 200

# %%
import requests

url = "https://ircsl.gov.lk/"
response = requests.get(url)
print(response.status_code)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     466 try:
# --> 467     self._validate_conn(conn)
#     468 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:1099, in HTTPSConnectionPool._validate_conn(self, conn)
#    1098 if conn.is_closed:
# -> 1099     conn.connect()
#    1101 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:653, in HTTPSConnection.connect(self)
#     651 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 653 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     654     sock=sock,
#     655     cert_reqs=self.cert_reqs,
#     656     ssl_version=self.ssl_version,
#     657     ssl_minimum_version=self.ssl_minimum_version,
#     658     ssl_maximum_version=self.ssl_maximum_version,
#     659     ca_certs=self.ca_certs,
#     660     ca_cert_dir=self.ca_cert_dir,
#     661     ca_cert_data=self.ca_cert_data,
#     662     cert_file=self.cert_file,
#     663     key_file=self.key_file,
#     664     key_password=self.key_password,
#     665     server_hostname=server_hostname_rm_dot,
#     666     ssl_context=self.ssl_context,
#     667     tls_in_tls=tls_in_tls,
#     668     assert_hostname=self.assert_hostname,
#     669     assert_fingerprint=self.assert_fingerprint,
#     670 )
#     671 self.sock = sock_and_verified.socket
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connection.py:806, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     804         server_hostname = normalized
# --> 806 ssl_sock = ssl_wrap_socket(
#     807     sock=sock,
#     808     keyfile=key_file,
#     809     certfile=cert_file,
#     810     key_password=key_password,
#     811     ca_certs=ca_certs,
#     812     ca_cert_dir=ca_cert_dir,
#     813     ca_cert_data=ca_cert_data,
#     814     server_hostname=server_hostname,
#     815     ssl_context=context,
#     816     tls_in_tls=tls_in_tls,
#     817 )
#     819 try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\ssl_.py:465, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     463     pass
# --> 465 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     466 return ssl_sock
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\ssl_.py:509, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     507     return SSLTransport(sock, ssl_context, server_hostname)
# --> 509 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Program Files\Python312\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Program Files\Python312\Lib\ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File c:\Program Files\Python312\Lib\ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:491, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     490         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 491     raise new_e
#     493 # conn.request() calls http.client.*.request, not the method in
#     494 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\connectionpool.py:847, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     845     new_e = ProtocolError("Connection aborted.", new_e)
# --> 847 retries = retries.increment(
#     848     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     849 )
#     850 retries.sleep()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='ircsl.gov.lk', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[9], line 4
#       1 import requests
#       3 url = "https://ircsl.gov.lk/"
# ----> 4 response = requests.get(url)
#       5 print(response.status_code)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     513         raise ProxyError(e, request=request)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
# --> 517         raise SSLError(e, request=request)
#     519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='ircsl.gov.lk', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))
