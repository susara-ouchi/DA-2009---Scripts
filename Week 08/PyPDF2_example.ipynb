# %% [markdown]
# ### Extract Text from a PDF

# %%
from PyPDF2 import PdfReader

reader = PdfReader("PDFs/example.pdf")
page = reader.pages[0]
print(page.extract_text())
# Out:
# Sample Document for PDF Placeholder Content
# This is a paragraph. It exists here to act as placeholder content.
# Random Paragraph
# Here is another random paragraph that serves as filler text.
# Bullet List Example:
#  " This is the first item in a list.
#  " This is the second item in the list.
#  " This is the third item in the list.
# Numbered List Example:
# 1. First step of the process.
# 2. Second step of the process.
# 3. Final step of the process.
# Sample Table
# ID
# Name
# Age
# Country
# 01
# John Doe
# 29
# USA
# 02
# Jane Smith
# 34
# Canada
# 03
# Alex Kim
# 41
# South Korea
# 04
# Maria Silva
# 25
# Brazil
# Another Table (with numbers):
# Year
# Revenue ($M)
# Expenses ($M)
# Profit ($M)
# 2020
# 120
# 100
# 20
# 2021
# 135
# 110
# 25
# 2022
# 160
# 130
# 30
# Placeholder Image
# [IMAGE PLACEHOLDER   imagine a rectangle here with caption below.]
# Figure 1: A sample figure representing where an image could be placed in a document.
# Sample Equations
# Inline example: The area of a circle is given by A = Àr².
# f:\UOC - Lectures\DA_2009 - Data Collection Methods 2\DA 2009 - Scripts\.venv\Lib\site-packages\PyPDF2\_cmap.py:142: PdfReadWarning: Advanced encoding /UniJIS-UCS2-H not implemented yet
#   warnings.warn(

# %% [markdown]
# #### Ignoring Headers and Footers

# %% [markdown]
# The following example reads the text of page 4 of this PDF document, but ignores header (y < 720) and footer (y > 50).

# %%
from PyPDF2 import PdfReader

reader = PdfReader("PDFs/GeoBase_NHNC1_Data_Model_UML_EN.pdf")
page = reader.pages[3]

parts = []


def visitor_body(text, cm, tm, fontDict, fontSize):
    y = tm[5]
    if y > 50 and y < 720:
        parts.append(text)


page.extract_text(visitor_text=visitor_body)
text_body = "".join(parts)

print(text_body)
# Out:
# TABLE OF CONTENTS
#
# 1 OVERVIEW  ................................ ................................ ................................ ................................ ............  6
# 2 LRS ................................ ................................ ................................ ................................ ........................  6
# 2.1 LRS  MODEL  ................................ ................................ ................................ ................................ ...... 7
# 3 MODEL  ................................ ................................ ................................ ................................ ..................  8
# 3.1 LRS  MODEL  ................................ ................................ ................................ ................................ ...... 9
# 3.1.1 Logical view  ................................ ................................ ................................ ...............................  9
# 3.1.2 Hydro network ................................ ................................ ................................ ..........................  10
# 3.1.3 Hydro events ................................ ................................ ................................ ............................  11
# 3.1.4 Hydrographic  ................................ ................................ ................................ ...........................  14
# 3.1.5 Topony my (external package)  ................................ ................................ ................................ . 18
# 3.1.6 Metadata  ................................ ................................ ................................ ................................ .. 19

# %%
from PyPDF2 import PdfReader
import svgwrite

reader = PdfReader("PDFs/GeoBase_NHNC1_Data_Model_UML_EN.pdf")
page = reader.pages[2]

dwg = svgwrite.Drawing("Images/GeoBase_test.svg", profile="tiny")


def visitor_svg_rect(op, args, cm, tm):
    if op == b"re":
        (x, y, w, h) = (args[i].as_numeric() for i in range(4))
        dwg.add(dwg.rect((x, y), (w, h), stroke="red", fill_opacity=0.05))


def visitor_svg_text(text, cm, tm, fontDict, fontSize):
    (x, y) = (tm[4], tm[5])
    dwg.add(dwg.text(text, insert=(x, y), fill="blue"))


page.extract_text(
    visitor_operand_before=visitor_svg_rect, visitor_text=visitor_svg_text
)
dwg.save()

# %% [markdown]
# #### Extracting Meta data

# %%
# Open a PDF file
with open('PDFs/example.pdf', 'rb') as pdf_file:
    pdf_reader = PdfReader(pdf_file)

    # Get the number of pages
    num_pages = len(pdf_reader.pages)
    print(f"The PDF has {num_pages} pages.")

    # Extract metadata
    metadata = pdf_reader.metadata
    print(metadata)
# Out:
# The PDF has 2 pages.
# {'/Author': '(anonymous)', '/CreationDate': "D:20250816135601+00'00'", '/Creator': '(unspecified)', '/Keywords': '', '/ModDate': "D:20250816135601+00'00'", '/Producer': 'ReportLab PDF Library - www.reportlab.com', '/Subject': '(unspecified)', '/Title': '(anonymous)', '/Trapped': '/False'}

# %% [markdown]
# #### Extracting Images

# %%
from PyPDF2 import PdfReader

reader = PdfReader("PDFs/DA 2009 - Week 1.pdf")

page = reader.pages[2]
page.images[0].name
page.images[0].data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc0\x00\x11\x08\x01\xb5\x01\xb5\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf9\xfe\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a\xbbig\xbe\x17\xb9\x91s\x1a\x0c\xe3\xd6\xa9\x93\x92O\xad6\xac\xae;\x12\xach\xb0\x89d\xc9\xdcp\xaa;\xfb\xd45,\x8e\x1e\x18\x87u\xc8"\xa2\xa1\x83\n(\xa7\xc5\x0c\x93\xc8#\x8dK1\xe8\x05!\x0c\xa2\xba+_\x0f\xdb\xc4\x03\xea\x17*\xa7\xfey\xa9\xe6\xb6,\x97\xc3\xf0J\xa2Ea\x1fvX\xf7\x13\xf9\xe2\xb6T[\xdcM\xf6W8\x81\x14\x87\xa4n~\x82\x83\x14\x8b\xd66\x1fQ^\xd1\xa4\xa7\x83n\x98,3\xe6C\xd1.T\'>\xdbkSR\xd3\xf4\xfbd\x0b\xfd\x8dj\xc8\xdfvV\x89J\xb7\xd0\x8e\xbf\x9dW\xb1O\xa9\xcf,O,\xac\xe2\xcf\x00\xa2\xbdj\xef\xc3Z-\xf6|\xcb?%\x8f\xf1\xc0\xc4\x11\xf8\x1c\x8f\xe5\\f\xbd\xe0\xcb\xad)\r\xcd\xb3\xfd\xaa\xd3?}F\n\xff\x00\xbc;\x7f/z\x89Q\x94M!Z2v9\x8a(\xe9Edj\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14QE\x00\x14\x0eH\xa2\x8a\x00\xec\xa2\xb5G\xd2\xbc\x94\x03\x0c\xb5\xca\\\xdaKk!WS\x80z\xd6\xe6\x8f{0\x8cG$NTw\xc5lI\x0cW)\xf3\xa6A\xf5\x185\xbbJH\xb6p\x94\xaa\xa5\x98*\x82I\xec+\xa8\x9f\xc3\xf6\xf2d\xa1(k_\xc2\xbfa\xf0\xf5\xf0\x9e\xebO\x82\xeeN\x88\xd7\x03r\xa9\xf5\x03\xa6\x7f\xde\x04T*m\xb2%\xa2\xbe\xe5_\x0e\xfc3\xd65\x9bu\xbe\xba\xdba\xa7\x9e|\xf9\xc1\xf9\x87\xfb*9o\xc0c\xde\xba{\x7f\x0cxv\xc23\x1d\xbc2\xde8\xf9Zi\xa4\xda\xa4\xfb*\x1e?\ ...

# %%
from PyPDF2 import PdfReader

reader = PdfReader("PDFs/DA 2009 - Week 1.pdf")

page = reader.pages[2]

count = 0
for image_file_object in page.images:
    save_path = f"Outputs/{image_file_object.name}"
    with open(save_path, "wb") as img_file:
        img_file.write(image_file_object.data)
        count += 1
        print(f"Saved the file {image_file_object.name} in the Outputs folder")
# Out:
# Saved the file Image60.jpg in the Outputs folder

# %% [markdown]
# #### Encrypt & Decrypt files

# %% [markdown]
# Encrypting

# %%
from PyPDF2 import PdfReader, PdfWriter

reader = PdfReader("PDFs/example.pdf")
writer = PdfWriter()

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Add a password to the new PDF
writer.encrypt("my-secret-password")

# Save the new PDF to a file
with open("encrypted-pdf.pdf", "wb") as f:
    writer.write(f)

# %% [markdown]
# Decrypting

# %%
from PyPDF2 import PdfReader, PdfWriter

reader = PdfReader("encrypted-pdf.pdf")
writer = PdfWriter()

if reader.is_encrypted:
    reader.decrypt("my-secret-password")

# Add all pages to the writer
for page in reader.pages:
    writer.add_page(page)

# Save the new PDF to a file
with open("decrypted-pdf.pdf", "wb") as f:
    writer.write(f)

# %% [markdown]
# #### Merging PDFs

# %%
from PyPDF2 import PdfWriter

merger = PdfWriter()

for pdf in ["file1.pdf", "file2.pdf", "file3.pdf"]:
    merger.append(pdf)

merger.write("merged-pdf.pdf")
merger.close()
